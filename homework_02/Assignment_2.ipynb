# %% [markdown]
# # 본 노트북 파일은 '파이썬이해와활용' 과제2에 대한 skeleton code 입니다.

# %% [markdown]
# # 문제 1

# %% [markdown]
# 무작위 은행 계좌번호를 생성하는 함수인 `account_number`의 코드를 완성하시오. `account_number_generator`함수로 생성되는 계좌번호는 3자리-2자리-6자리 형태(예: `001-24-554421`)로 구성되어야 합니다. 계좌번호의 3번째 자리, 5번째 자리 뒤에는 ‘-’ 가 있어야 합니다(예: `001-24-554421`).
#
# `firstNumber()`, `secondNumber()`, `thirdNumber()` 함수를 활용하여 `account_number_generator` 함수의 코드를 완성하여야 합니다. `firstNumber()` 함수는 계죄번호 첫 3자리를 위한 1\~999 사이의 난수(무작위 번호)를 생성합니다. `secondNumber()` 함수는 계좌번호 가운데 2자리를 위한 1\~99 사이의 난수를 생성합니다. `thirdNumber()` 함수는 계좌번호 마지막 6자리를 위한 1\~999999 사이의 난수를 생성합니다.
#
# `firstNumber()`, `secondNumber()`, `thirdNumber()` 함수로 생성된 난수의 자리수가 해당 계좌번호 자리수보다 적으면 0을 앞에 붙여 자리수를 맞추어야 합니다. 예를 들어 `thirdNumber()` 함수로 생성된 난수가 `102`면 앞에 0를 3개 붙여서 자리수가 6개(`000102`)가 되도록 하여야 한다.

# %%
import random

def getRandomNumber(digit):
  return random.randint(1, 10**digit-1)

def firstNumber():
  return getRandomNumber(3)

def secondNumber():
  return getRandomNumber(2)

def thirdNumber():
  return getRandomNumber(6)

def account_number_generator():
    account_number = None
    ### Modify code here ###


    ### End of your code ###
    return account_number

# %%
print(account_number_generator())
# Out:
# 001-24-554421

# %% [markdown]
# # 문제 2

# %% [markdown]
# 학생의 정보를 저장하기 위한 Student 클래스를 정의하고자 한다. 다음을 고려하여 `Student` 클래스를 코드를 완성하시오.
#
# 1. 학생의 이름(name)과 학번(id)를 입력받는 생성자 메소드 `__init__(self, name, id)`의 코드를 완성하시오.
#
# 2. 학생의 이름과 학번을 출력하는 메서드 print_info(self)의 코드를 완성하시오(출력 형식: `이름: <name>, 학번: <id>`). 예컨대 이름이 홍길동이고 학번이 11132명 출력 결과는 다음과 같다: `이름: 홍길동, 학번: 11132`.

# %%
class Student:

    def __init__(self, name, id):
    ### Modify code here ###


    ### End of your code ###

    def print_info(self):
    ### Modify code here ###



    ### End of your code ###

# %%
st1 = Student("홍길동", "11132")
st1.print_info()
# Out:
# 이름: 홍길동, 학번: 11132

# %% [markdown]
# # 문제 3

# %% [markdown]
# 다음과 같이 과자의 이름 및 정보(가격 및 중량)를 저장한 딕셔너리 snack이 있을 때, 과자의 이름으로 검색하여 정보를 출력하는 함수 snack_search(name)의 코드를 완성하시오. 입력된 과자의 이름이 검색되지 않는 경우는 ‘저장된 정보가 없습니다’라고 출력하여야 한다.

# %%
import random

snack = {"새우깡": [1200, 300], "감자깡": [1100, 280], "양파깡": [1250, 310], "감자칩": [1200, 150], "양파 나라": [1500, 300], "감자칩 수미감자": [1250, 150]}

def snack_search(name):
    ### Modify code here ###



    ### End of your code ###

# %%
snack_search("새우깡")
# Out:
# 가격: 1200원, 중량: 300g

# %%
snack_search("콘치즈")
# Out:
# 저장된 정보가 없습니다.
